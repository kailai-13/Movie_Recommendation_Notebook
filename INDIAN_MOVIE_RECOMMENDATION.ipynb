# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

mv_d=pd.read_csv('/content/indian movies.csv')

mv_d=mv_d[:20000]

s_fea=mv_d[['Genre','Language','Rating(10)','Timing(min)','Year']]
for f in s_fea:
  mv_d[f]=mv_d[f].fillna('')

com = mv_d['Genre'] + ' ' + mv_d['Language'] + ' ' + mv_d['Rating(10)'] + ' ' + mv_d['Timing(min)'] + ' ' + mv_d['Year']

vectorizer=TfidfVectorizer()
f_vectors=vectorizer.fit_transform(com)

sim=cosine_similarity(f_vectors)

# %%
mv_d.head()
# Out:
#           ID               MovieName  Year Timing(min) Rating(10)  Votes  \
# 0  tt0398974             Dr. Shaitan  1960           -          -      -
# 1  tt1702558              Nadir Khan  1968           -          -      -
# 2  tt0493437  Apna Sapna Money Money  2006     134 min        5.3  1,892
# 3  tt0273405          Aag Aur Sholay  1987           -        2.2     20
# 4  tt0049595                 Parivar  1956           -        7.4     21
#
#                                   Genre Language  Index
# 0                                     -    hindi      0
# 1                                     -     urdu      1
# 2  Comedy, Musical, Romance                hindi      2
# 3                                     -     urdu      3
# 4     Comedy, Drama, Family                hindi      4

# %%
mv_m=input('Enter Your Fav Movie Name:')

list_all=mv_d['MovieName'].tolist()

find=difflib.get_close_matches(mv_m,list_all)

cmatch=find[0]

index_m=mv_d[mv_d.MovieName==cmatch]['Index'].values[0]

sim_score=list(enumerate(sim[index_m]))

sort_sim_m=sorted(sim_score,key=lambda x:x[1] ,reverse=True)
print('Movies suggested for you : \n')

i = 1

for movie in sort_sim_m:
  index = movie[0]
  title_from_index = mv_d[mv_d.index==index]['MovieName'].values[0]
  rating=mv_d[mv_d.index==index]['Rating(10)'].values[0]
  time=mv_d[mv_d.index==index]['Timing(min)'].values[0]
  if (i<30):
    print(i, '.',title_from_index,'-',rating,'Duration:',time)
    i+=1
# Out:
# Enter Your Fav Movie Name:puli
# Movies suggested for you :
#
# 1 . Suli - - Duration: 137 min
# 2 . Bhale Huduga - - Duration: 137 min
# 3 . Kondura (The Sage from the Sea) - 7.4 Duration: 137 min
# 4 . Nanna Prayashchitta - - Duration: -
# 5 . Muyyige Muyyi - - Duration: -
# 6 . Kiru Minkanaja - - Duration: 137 min
# 7 . Anveshi - - Duration: 137 min
# 8 . Sri Omkara Ayyappane - - Duration: 137 min
# 9 . Meravanige - - Duration: 137 min
# 10 . Benkiya Bale - 6.7 Duration: 137 min
# 11 . Tyson - 5.1 Duration: 137 min
# 12 . Maha Prachandaru - 8 Duration: 137 min
# 13 . Karunamayi - - Duration: 137 min
# 14 . Devadasi - - Duration: -
# 15 . Dia - 8.1 Duration: 137 min
# 16 . Agni IPS - 7.9 Duration: 137 min
# 17 . Ricky - 7.9 Duration: 137 min
# 18 . Murali Meets Meera - 6.1 Duration: 137 min
# 19 . Singaporenalli Raja Kulla - 7.7 Duration: 143 min
# 20 . Grahana - - Duration: 121 min
# 21 . Amar Suhagin - - Duration: -
# 22 . Paduvarahalli Pandavaru - 8 Duration: 146 min
# 23 . Mr. Theertha - 6.4 Duration: 137 min
# 24 . Mane - 6.6 Duration: 137 min
# 25 . Sampoorna Sant Darshanam - - Duration: -
# 26 . Hind Ki Wali - - Duration: -
# 27 . Karunamoyee - - Duration: -
# 28 . Kharidaar - - Duration: -
# 29 . Habba Khatoon - - Duration: -
